# %% [markdown]
# # CBAG UAV1 (placeholder)
#
# The full cleaned notebook is large. Please download the original from the project folder or contact the author to push the complete version.
#
# Repo structure is ready. Add the three notebooks (CBAG_UAV1_clean.ipynb, CBAG_AccessPoint_clean.ipynb, CBAG_GSC_clean.ipynb) via GitHub web UI or git.
