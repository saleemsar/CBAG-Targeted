# %% [markdown]
# # CBAG UAV1 — Full cleaned notebook
#
# **Please replace this file** by uploading the complete `CBAG_UAV1_clean.ipynb` from the project artifacts.
#
# The cleaned version preserves 100% of the original code functionality (all generators, phases, Tri-Gate, caching, etc.).
# Only empty cells were removed and the title/docs improved.
#
# Same for `CBAG_AccessPoint_clean.ipynb` and `CBAG_GSC_clean.ipynb`.
#
# Repo: https://github.com/saleemsar/CBAG-Targeted
